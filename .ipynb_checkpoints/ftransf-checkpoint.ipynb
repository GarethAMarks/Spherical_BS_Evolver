# %%
import matplotlib.pyplot as plt
import numpy as np

dt = 0.04004
file = open('ftransf.dat', 'r')

times = []
A0vals = []

lines = file.readlines()

for l in lines:
    times.append(float(l.split('    ')[0]))
    A0vals.append(float(l.split('    ')[1]))
    
for index,n in enumerate(A0vals):
        A0vals[index] = float(n)

wvals = np.fft.fft(A0vals)

plt.plot(wvals)
plt.xlim(0, 1)

#print(wvals)
# Out:
# [9.92324515e+02-3.53259089e-14j 3.46367024e-02-2.15294617e+00j
#  3.39156526e-02-1.08025262e+00j ... 4.80388954e-02+7.27585869e-01j
#  3.39156526e-02+1.08025262e+00j 3.46367024e-02+2.15294617e+00j]
